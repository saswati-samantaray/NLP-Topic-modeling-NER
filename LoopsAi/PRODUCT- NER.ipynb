# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
import pandas as pd
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
import spacy
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
nlp = spacy.load("en_core_web_sm")
# Out:
# [nltk_data] Downloading package punkt to /Users/SaswatiS/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/SaswatiS/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# /Users/SaswatiS/opt/anaconda3/envs/paylocity_lms/lib/python3.8/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
df=pd.read_csv('ticketmaster.csv')
print(df.shape)
df.head()
# Out:
# (9964, 15)
#    line_num                            title   createdTime  status priority  \
# 0       0.0             Scan my computer now  1.574306e+09  Closed     High
# 1       1.0         how to find address book  1.579539e+09  Closed      Low
# 2       2.0                       Solution 2  1.577330e+09  Closed   Medium
# 3       3.0  real time scanning wont turn on  1.575271e+09  Closed      Low
# 4       4.0                           Refund  1.588172e+09  Closed      Low
#
#                      extId user.identity.name user.identity.displayName  \
# 0  stuart.thomson@acme.com     Stuart Thomson            Stuart Thomson
# 1    peter.macron@acme.com       Peter Macron              Peter Macron
# 2  victoria.lewis@acme.com     Victoria Lewis            Victoria Lewis
# 3     vincent.lee@acme.com        Vincent Lee               Vincent Lee
# 4    kim.anderson@acme.com       Kim Anderson              Kim Anderson
#
#               user.emailId     user.department  \
# 0  stuart.thomson@acme.com                  HR
# 1    peter.macron@acme.com         Engineering
# 2  victoria.lewis@acme.com               Legal
# 3     vincent.lee@acme.com             Culture
# 4    kim.anderson@acme.com  Product & Services
#
#                              extId.1  integrationId user.identity.name.1  \
# 0  gearldine_gellinger@gellinger.com            1.0            Gearldine
# 1             lnewville@newville.com            1.0                Lenna
# 2      virgina_tegarden@tegarden.com            1.0              Virgina
# 3                   tfrankel@aol.com            1.0                Tiera
# 4            norah.waymire@gmail.com            1.0                Norah
#
#   user.identity.displayName.1                     user.emailId.1
# 0         Gearldine Gellinger  gearldine_gellinger@gellinger.com
# 1              Lenna Newville             lnewville@newville.com
# 2            Virgina Tegarden      virgina_tegarden@tegarden.com
# 3               Tiera Frankel                   tfrankel@aol.com
# 4               Norah Waymire            norah.waymire@gmail.com

# %%
df.dropna(inplace=True)

# %%
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# %%
processed_docs = []

for doc in df['title']:
    processed_docs.append(preprocess(doc))
    
print(processed_docs[:2])
# Out:
# [[('Scan', 'JJ'), ('my', 'PRP$'), ('computer', 'NN'), ('now', 'RB')], [('how', 'WRB'), ('to', 'TO'), ('find', 'VB'), ('address', 'JJ'), ('book', 'NN')]]

# %%
# Tokenize and lemmatize
def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(text) :
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(token)
            
    return result

# %%
#Preprocess

df['clean_title']= df['title'].apply(lambda x: preprocess(x))

# %%
sentences = [x for x in df.clean_title]
print(sentences[1])
# Out:
# ['address', 'book']

# %%
def apply_tag(index):
    return [(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[int(index)])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]

# %%
df['tags']= df['line_num'].apply(lambda x: apply_tag(x))
df.head()
# Out:
#    line_num                            title   createdTime  status priority  \
# 0       0.0             Scan my computer now  1.574306e+09  Closed     High
# 1       1.0         how to find address book  1.579539e+09  Closed      Low
# 2       2.0                       Solution 2  1.577330e+09  Closed   Medium
# 3       3.0  real time scanning wont turn on  1.575271e+09  Closed      Low
# 4       4.0                           Refund  1.588172e+09  Closed      Low
#
#                      extId user.identity.name user.identity.displayName  \
# 0  stuart.thomson@acme.com     Stuart Thomson            Stuart Thomson
# 1    peter.macron@acme.com       Peter Macron              Peter Macron
# 2  victoria.lewis@acme.com     Victoria Lewis            Victoria Lewis
# 3     vincent.lee@acme.com        Vincent Lee               Vincent Lee
# 4    kim.anderson@acme.com       Kim Anderson              Kim Anderson
#
#               user.emailId     user.department  \
# 0  stuart.thomson@acme.com                  HR
# 1    peter.macron@acme.com         Engineering
# 2  victoria.lewis@acme.com               Legal
# 3     vincent.lee@acme.com             Culture
# 4    kim.anderson@acme.com  Product & Services
#
#                              extId.1  integrationId user.identity.name.1  \
# 0  gearldine_gellinger@gellinger.com            1.0            Gearldine
# 1             lnewville@newville.com            1.0                Lenna
# 2      virgina_tegarden@tegarden.com            1.0              Virgina
# 3                   tfrankel@aol.com            1.0                Tiera
# 4            norah.waymire@gmail.com            1.0                Norah
#
#   user.identity.displayName.1                     user.emailId.1  \
# 0         Gearldine Gellinger  gearldine_gellinger@gellinger.com
# 1              Lenna Newville             lnewville@newville.com
# 2            Virgina Tegarden      virgina_tegarden@tegarden.com
# 3               Tiera Frankel                   tfrankel@aol.com
# 4               Norah Waymire            norah.waymire@gmail.com
#
#                           clean_title  \
# 0                              [scan]
# 1                     [address, book]
# 2                          [solution]
# 3  [real, time, scanning, wont, turn]
# 4                            [refund]
#
#                                                 tags
# 0                              [(scan, PROPN, scan)]
# 1     [(address, NOUN, address), (book, NOUN, book)]
# 2                       [(solution, NOUN, solution)]
# 3  [(real, ADJ, real), (time, NOUN, time), (scann...
# 4                           [(refund, NOUN, refund)]

# %%
# df.dropna(inplace=True)

# %%
def cleanup_propn(sentence):
    ret_list = []
    for i in sentence:
#         print(i)
        if 'PROPN'in i:
            ret_list.append(i)
            
    return ret_list

# %%
df['PropN_cleanup'] = df['tags'].apply(lambda x: cleanup_propn(x))

df.head()
# Out:
#    line_num                            title   createdTime  status priority  \
# 0       0.0             Scan my computer now  1.574306e+09  Closed     High
# 1       1.0         how to find address book  1.579539e+09  Closed      Low
# 2       2.0                       Solution 2  1.577330e+09  Closed   Medium
# 3       3.0  real time scanning wont turn on  1.575271e+09  Closed      Low
# 4       4.0                           Refund  1.588172e+09  Closed      Low
#
#                      extId user.identity.name user.identity.displayName  \
# 0  stuart.thomson@acme.com     Stuart Thomson            Stuart Thomson
# 1    peter.macron@acme.com       Peter Macron              Peter Macron
# 2  victoria.lewis@acme.com     Victoria Lewis            Victoria Lewis
# 3     vincent.lee@acme.com        Vincent Lee               Vincent Lee
# 4    kim.anderson@acme.com       Kim Anderson              Kim Anderson
#
#               user.emailId     user.department  \
# 0  stuart.thomson@acme.com                  HR
# 1    peter.macron@acme.com         Engineering
# 2  victoria.lewis@acme.com               Legal
# 3     vincent.lee@acme.com             Culture
# 4    kim.anderson@acme.com  Product & Services
#
#                              extId.1  integrationId user.identity.name.1  \
# 0  gearldine_gellinger@gellinger.com            1.0            Gearldine
# 1             lnewville@newville.com            1.0                Lenna
# 2      virgina_tegarden@tegarden.com            1.0              Virgina
# 3                   tfrankel@aol.com            1.0                Tiera
# 4            norah.waymire@gmail.com            1.0                Norah
#
#   user.identity.displayName.1                     user.emailId.1  \
# 0         Gearldine Gellinger  gearldine_gellinger@gellinger.com
# 1              Lenna Newville             lnewville@newville.com
# 2            Virgina Tegarden      virgina_tegarden@tegarden.com
# 3               Tiera Frankel                   tfrankel@aol.com
# 4               Norah Waymire            norah.waymire@gmail.com
#
#                           clean_title  \
# 0                              [scan]
# 1                     [address, book]
# 2                          [solution]
# 3  [real, time, scanning, wont, turn]
# 4                            [refund]
#
#                                                 tags          PropN_cleanup
# 0                              [(scan, PROPN, scan)]  [(scan, PROPN, scan)]
# 1     [(address, NOUN, address), (book, NOUN, book)]                     []
# 2                       [(solution, NOUN, solution)]                     []
# 3  [(real, ADJ, real), (time, NOUN, time), (scann...                     []
# 4                           [(refund, NOUN, refund)]                     []

# %%
len(df[df["PropN_cleanup"].str.len() != 0])
# Out:
# 1535

# %%
# df[df["PropN_cleanup"].str.len() ==4]

# %%
def pick_first_noun(sentence):
    ret_list = []
    for i in sentence:
        
        ret_list.append(i[0])
            
    str1 = ' '.join(ret_list)
    
    return str1

# %%
df['PropN_words'] = df['PropN_cleanup'].apply(lambda x: pick_first_noun(x))

df.head()
# Out:
#    line_num                            title   createdTime  status priority  \
# 0       0.0             Scan my computer now  1.574306e+09  Closed     High
# 1       1.0         how to find address book  1.579539e+09  Closed      Low
# 2       2.0                       Solution 2  1.577330e+09  Closed   Medium
# 3       3.0  real time scanning wont turn on  1.575271e+09  Closed      Low
# 4       4.0                           Refund  1.588172e+09  Closed      Low
#
#                      extId user.identity.name user.identity.displayName  \
# 0  stuart.thomson@acme.com     Stuart Thomson            Stuart Thomson
# 1    peter.macron@acme.com       Peter Macron              Peter Macron
# 2  victoria.lewis@acme.com     Victoria Lewis            Victoria Lewis
# 3     vincent.lee@acme.com        Vincent Lee               Vincent Lee
# 4    kim.anderson@acme.com       Kim Anderson              Kim Anderson
#
#               user.emailId     user.department  \
# 0  stuart.thomson@acme.com                  HR
# 1    peter.macron@acme.com         Engineering
# 2  victoria.lewis@acme.com               Legal
# 3     vincent.lee@acme.com             Culture
# 4    kim.anderson@acme.com  Product & Services
#
#                              extId.1  integrationId user.identity.name.1  \
# 0  gearldine_gellinger@gellinger.com            1.0            Gearldine
# 1             lnewville@newville.com            1.0                Lenna
# 2      virgina_tegarden@tegarden.com            1.0              Virgina
# 3                   tfrankel@aol.com            1.0                Tiera
# 4            norah.waymire@gmail.com            1.0                Norah
#
#   user.identity.displayName.1                     user.emailId.1  \
# 0         Gearldine Gellinger  gearldine_gellinger@gellinger.com
# 1              Lenna Newville             lnewville@newville.com
# 2            Virgina Tegarden      virgina_tegarden@tegarden.com
# 3               Tiera Frankel                   tfrankel@aol.com
# 4               Norah Waymire            norah.waymire@gmail.com
#
#                           clean_title  \
# 0                              [scan]
# 1                     [address, book]
# 2                          [solution]
# 3  [real, time, scanning, wont, turn]
# 4                            [refund]
#
#                                                 tags          PropN_cleanup  \
# 0                              [(scan, PROPN, scan)]  [(scan, PROPN, scan)]
# 1     [(address, NOUN, address), (book, NOUN, book)]                     []
# 2                       [(solution, NOUN, solution)]                     []
# 3  [(real, ADJ, real), (time, NOUN, time), (scann...                     []
# 4                           [(refund, NOUN, refund)]                     []
#
#   PropN_words
# 0        scan
# 1
# 2
# 3
# 4

# %%
#Top proper nouns identified

df.PropN_words.str.split(expand = True).stack().value_counts()[:50]
# Out:
# acme              721
# scan              114
# product_launch     56
# robinson           37
# alex               33
# jackson            33
# peter              33
# antivirus          28
# thomson            27
# anna               27
# anderson           24
# jacob              24
# smith              24
# trojan             24
# mcfee              23
# johnson            23
# scott              22
# maria              22
# lisa               21
# lopez              21
# login              19
# juan               17
# dell               17
# saina              17
# technician         17
# bradley            16
# archer             16
# mcaffe             16
# victoria           15
# taylor             15
# mitchell           15
# karun              15
# john               14
# wag_bpfl           14
# gibson             14
# elisabeth          13
# malware            13
# demos              12
# parker             12
# brandon            12
# google             11
# wag_bpgv           11
# andrew             11
# eric               11
# hola               11
# erica              10
# clark              10
# macron             10
# march               8
# microsoft           8
# dtype: int64

# %% [markdown]
# #### ACME, Trojan, Mcfee, Dell are a few notable products that show up in the top 40 Proper noun entity
